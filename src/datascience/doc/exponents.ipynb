# %% [markdown]
# ![Alt text](images/exponents.png)

# %%
result = 2**3
print(result) # 8

# %% [markdown]
# ![Alt text](images/exponents2.png) </br>
# ![Alt text](images/exponents2-result.png)

# %%
from sympy import symbols
x = symbols('x')
result = x**2 / x**5
print(result) #x**(-3)

# %% [markdown]
# ![Alt text](images/exponents3.png)

# %% [markdown]
# ![Alt text](images/exponents4.png)

# %% [markdown]
# ![Alt text](images/exponents5.png)

# %% [markdown]
# And one last property: an exponent of an exponent will multiply the exponents
# together. This is known as the power rule. So ![Alt text](images/exponents-text.png)
#  would simplify to 86:
#
# ![Alt text](images/exponents6.png)

# %% [markdown]
# If you are skeptical why this is, try expanding it and you will see the sum rule makes it
# clear:
# ![Alt](images/exponents7.png)

# %% [markdown]
# Lastly, what does it mean when we have a fractional exponent with a numerator other
# than 1, such as 8
# 2
# 3? Well, that is taking the cube root of 8 and then squaring it. Take a
# look:
#
# ![Alt text](images/exponents8.png)

# %% [markdown]
# And yes, irrational numbers can serve as exponents like 8π, which is 687.2913. This
# may feel unintuitive, and understandably so! In the interest of time, we will not
# dive deep into this as it requires some calculus. But essentially, we can calculate
# irrational exponents by approximating with a rational number. This is effectively
# what computers do since they can compute to only so many decimal places anyway.
# For example π has an infinite number of decimal places. But if we take the first 11
# digits, 3.1415926535, we can approximate π as a rational number 31415926535 /
# 10000000000. Sure enough, this gives us approximately 687.2913, which should
# approximately match any calculator:
#
# ![Alt text](images/exponents9.png)
