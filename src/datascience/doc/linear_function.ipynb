# %% [markdown]
# ![Alt text](images/liners_func_img.png)

# %%
from sympy import *
x = symbols('x')
f = 2*x + 1
plot(f)
# Out:
#      21 |                                                     ..
#         |                                                  ...
#         |                                                ..
#         |                                             ...
#         |                                          ...
#         |                                        ..
#         |                                     ...
#         |                                  ...
#         |                                ..
#         |                             ...
#       1 |--------------------------...--------------------------
#         |                       ...
#         |                     ..
#         |                  ...
#         |               ...
#         |             ..
#         |          ...
#         |       ...
#         |     ..
#         |  ...
#     -19 |_______________________________________________________
# ...

# %% [markdown]
#  ![Alt text](images/liners_func_img2.png)

# %%
f = x**2 + 1
plot(f)
# Out:
#     100 |\                                                     /
#         | .                                                   .
#         |
#         |  .                                                 .
#         |   \                                               /
#         |    .                                             .
#         |
#         |     .                                           .
#         |      \                                         /
#         |       \                                       /
#      50 |--------\-------------------------------------/--------
#         |         \                                   /
#         |          \                                 /
#         |           \                               /
#         |            ..                           ..
#         |              \                         /
#         |               ..                     ..
#         |                 \                   /
# ...

# %% [markdown]
# ![Alt text](images/liners_func_img3.png)

# %%
from sympy import symbols
from sympy.plotting import plot3d
x, y= symbols('x y')
f = 2*x + 3*y
plot3d(f)
